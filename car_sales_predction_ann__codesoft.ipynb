# %% [markdown]
# <a href="https://colab.research.google.com/github/satwika1706/Codsoft_Internship/blob/main/car_sales_predction_ann__codesoft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %% [markdown]
# Data Preprocessing

# %%
df = pd.read_csv('/content/sales_task4.csv', encoding='ISO-8859-1')

# Check the first few rows of the dataset
print(df.head())
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %% [markdown]
# Drop unneeded columns

# %%
df.drop(columns=['customer name', 'customer e-mail', 'country', 'gender'], inplace=True)

# %% [markdown]
# Define X and y

# %%
X = df.drop('car purchase amount', axis=1)
y = df['car purchase amount']

# %% [markdown]
# Data Scaling

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y.values.reshape(-1, 1))

# %% [markdown]
# Data Splitting

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (400, 4)
# (400, 1)
# (100, 4)
# (100, 1)

# %% [markdown]
# Modal Structure

# %%
model = Sequential()
model.add(Dense(10, activation='relu', input_dim=4))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='linear'))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                50
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 171 (684.00 Byte)
# Trainable params: 171 (684.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Modal Training

# %%
history = model.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 26ms/step - loss: 0.3700 - mean_absolute_error: 0.5850 - val_loss: 0.3333 - val_mean_absolute_error: 0.5508
# Epoch 2/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2699 - mean_absolute_error: 0.4942 - val_loss: 0.2362 - val_mean_absolute_error: 0.4573
# Epoch 3/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1827 - mean_absolute_error: 0.3994 - val_loss: 0.1522 - val_mean_absolute_error: 0.3582
# Epoch 4/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1084 - mean_absolute_error: 0.2997 - val_loss: 0.0816 - val_mean_absolute_error: 0.2487
# Epoch 5/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0481 - mean_absolute_error: 0.1876 - val_loss: 0.0309 - val_mean_absolute_error: 0.1397
# Epoch 6/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0181 - mean_absolute_error: 0.1066 - val_loss: 0.0192 - val_mean_absolute_error: 0.1114
# Epoch 7/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0175 - mean_absolute_error: 0.1033 - val_loss: 0.0184 - val_mean_absolute_error: 0.1091
# Epoch 8/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0150 - mean_absolute_error: 0.0952 - val_loss: 0.0160 - val_mean_absolute_error: 0.1013
# Epoch 9/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0137 - mean_absolute_error: 0.0912 - val_loss: 0.0157 - val_mean_absolute_error: 0.0988
# Epoch 10/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0131 - mean_absolute_error: 0.0900 - val_loss: 0.0147 - val_mean_absolute_error: 0.0947
# Epoch 11/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0123 - mean_absolute_error: 0.0870 - val_loss: 0.0134 - val_mean_absolute_error: 0.0903
# Epoch 12/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0116 - mean_absolute_error: 0.0845 - val_loss: 0.0125 - val_mean_absolute_error: 0.0870
# Epoch 13/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0111 - mean_absolute_error: 0.0826 - val_loss: 0.0118 - val_mean_absolute_error: 0.0855
# Epoch 14/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0105 - mean_absolute_error: 0.0805 - val_loss: 0.0114 - val_mean_absolute_error: 0.0831
# Epoch 15/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0100 - mean_absolute_error: 0.0788 - val_loss: 0.0108 - val_mean_absolute_error: 0.0813
# Epoch 16/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0094 - mean_absolute_error: 0.0765 - val_loss: 0.0105 - val_mean_absolute_error: 0.0793
# Epoch 17/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0090 - mean_absolute_error: 0.0747 - val_loss: 0.0099 - val_mean_absolute_error: 0.0777
# Epoch 18/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0085 - mean_absolute_error: 0.0726 - val_loss: 0.0095 - val_mean_absolute_error: 0.0757
# Epoch 19/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0079 - mean_absolute_error: 0.0705 - val_loss: 0.0090 - val_mean_absolute_error: 0.0736
# Epoch 20/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0074 - mean_absolute_error: 0.0683 - val_loss: 0.0085 - val_mean_absolute_error: 0.0717
# Epoch 21/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0069 - mean_absolute_error: 0.0662 - val_loss: 0.0080 - val_mean_absolute_error: 0.0699
# Epoch 22/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0064 - mean_absolute_error: 0.0638 - val_loss: 0.0075 - val_mean_absolute_error: 0.0676
# Epoch 23/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0060 - mean_absolute_error: 0.0616 - val_loss: 0.0070 - val_mean_absolute_error: 0.0654
# Epoch 24/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0055 - mean_absolute_error: 0.0590 - val_loss: 0.0065 - val_mean_absolute_error: 0.0629
# Epoch 25/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0050 - mean_absolute_error: 0.0564 - val_loss: 0.0060 - val_mean_absolute_error: 0.0604
# Epoch 26/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0045 - mean_absolute_error: 0.0539 - val_loss: 0.0055 - val_mean_absolute_error: 0.0579
# Epoch 27/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0041 - mean_absolute_error: 0.0512 - val_loss: 0.0050 - val_mean_absolute_error: 0.0551
# Epoch 28/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0036 - mean_absolute_error: 0.0484 - val_loss: 0.0046 - val_mean_absolute_error: 0.0528
# Epoch 29/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0033 - mean_absolute_error: 0.0460 - val_loss: 0.0042 - val_mean_absolute_error: 0.0503
# Epoch 30/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0029 - mean_absolute_error: 0.0430 - val_loss: 0.0038 - val_mean_absolute_error: 0.0480
# Epoch 31/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0026 - mean_absolute_error: 0.0409 - val_loss: 0.0034 - val_mean_absolute_error: 0.0454
# Epoch 32/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0022 - mean_absolute_error: 0.0380 - val_loss: 0.0030 - val_mean_absolute_error: 0.0428
# Epoch 33/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0020 - mean_absolute_error: 0.0356 - val_loss: 0.0026 - val_mean_absolute_error: 0.0402
# Epoch 34/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0017 - mean_absolute_error: 0.0331 - val_loss: 0.0023 - val_mean_absolute_error: 0.0375
# Epoch 35/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0015 - mean_absolute_error: 0.0308 - val_loss: 0.0020 - val_mean_absolute_error: 0.0351
# Epoch 36/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0013 - mean_absolute_error: 0.0287 - val_loss: 0.0018 - val_mean_absolute_error: 0.0326
# Epoch 37/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0011 - mean_absolute_error: 0.0266 - val_loss: 0.0015 - val_mean_absolute_error: 0.0306
# Epoch 38/50
# 10/10 [==============================] - 0s 10ms/step - loss: 9.5139e-04 - mean_absolute_error: 0.0245 - val_loss: 0.0013 - val_mean_absolute_error: 0.0279
# Epoch 39/50
# 10/10 [==============================] - 0s 10ms/step - loss: 7.8837e-04 - mean_absolute_error: 0.0225 - val_loss: 0.0012 - val_mean_absolute_error: 0.0257
# Epoch 40/50
# 10/10 [==============================] - 0s 11ms/step - loss: 6.7627e-04 - mean_absolute_error: 0.0209 - val_loss: 0.0010 - val_mean_absolute_error: 0.0237
# Epoch 41/50
# 10/10 [==============================] - 0s 9ms/step - loss: 5.6878e-04 - mean_absolute_error: 0.0190 - val_loss: 8.6708e-04 - val_mean_absolute_error: 0.0219
# Epoch 42/50
# 10/10 [==============================] - 0s 8ms/step - loss: 4.8463e-04 - mean_absolute_error: 0.0176 - val_loss: 7.5301e-04 - val_mean_absolute_error: 0.0201
# Epoch 43/50
# 10/10 [==============================] - 0s 9ms/step - loss: 4.1289e-04 - mean_absolute_error: 0.0161 - val_loss: 6.5540e-04 - val_mean_absolute_error: 0.0184
# Epoch 44/50
# 10/10 [==============================] - 0s 9ms/step - loss: 3.5405e-04 - mean_absolute_error: 0.0150 - val_loss: 5.8190e-04 - val_mean_absolute_error: 0.0169
# Epoch 45/50
# 10/10 [==============================] - 0s 9ms/step - loss: 3.0126e-04 - mean_absolute_error: 0.0137 - val_loss: 5.0320e-04 - val_mean_absolute_error: 0.0156
# Epoch 46/50
# 10/10 [==============================] - 0s 9ms/step - loss: 2.5847e-04 - mean_absolute_error: 0.0126 - val_loss: 4.5166e-04 - val_mean_absolute_error: 0.0143
# Epoch 47/50
# 10/10 [==============================] - 0s 10ms/step - loss: 2.2620e-04 - mean_absolute_error: 0.0117 - val_loss: 3.9572e-04 - val_mean_absolute_error: 0.0134
# Epoch 48/50
# 10/10 [==============================] - 0s 9ms/step - loss: 1.9333e-04 - mean_absolute_error: 0.0107 - val_loss: 3.7141e-04 - val_mean_absolute_error: 0.0125
# Epoch 49/50
# 10/10 [==============================] - 0s 10ms/step - loss: 1.7752e-04 - mean_absolute_error: 0.0102 - val_loss: 3.2559e-04 - val_mean_absolute_error: 0.0116
# Epoch 50/50
# 10/10 [==============================] - 0s 6ms/step - loss: 1.5856e-04 - mean_absolute_error: 0.0096 - val_loss: 3.0709e-04 - val_mean_absolute_error: 0.0110

# %% [markdown]
# independent and dependent variables

# %%
# Define needed variables
tr_acc = history.history['mean_absolute_error']
tr_loss = history.history['loss']
val_acc = history.history['val_mean_absolute_error']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %% [markdown]
# Prediction

# %%
y_pred = model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import r2_score

R2 = r2_score(y_test, y_pred)
print("R2 Score=",R2 )
# Out:
# R2 Score= 0.9914709531520602
